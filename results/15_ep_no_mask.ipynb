# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitryKutsev/congrats_generator/blob/feature%234/my_gpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huggingface/transformers.git
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 93155, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 93155 (delta 9), reused 44 (delta 7), pack-reused 93095
# Receiving objects: 100% (93155/93155), 77.76 MiB | 13.04 MiB/s, done.
# Resolving deltas: 100% (67382/67382), done.

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("sberbank-ai/rugpt3small_based_on_gpt2")

# %%
import os
os.getcwd()
# Out:
# '/home/cola-pirat/embedika/congrats_generator'

# %%
from transformers import pipeline

generator = pipeline('text-generation',
              model='/home/cola-pirat/embedika/congrats_generator/my_app/models/15_epochs_without_masks_model',
              use_auth=False,
              tokenizer=tokenizer, 
              max_length=500)

# %%
generator("Диме")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Диме")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Александру")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Александру")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Станиславу")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Станиславу")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Денису")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Денису")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Петру")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Петру")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Кириллу")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("Кириллу")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("завод Заря")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("завод Заря")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("лагерь Тройничок")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("лагерь Тройничок")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("предприятие Сапфир")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("предприятие Сапфир")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("ООО Молот")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("ООО Молот")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("достопричудный псоглавец")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("достопричудный псоглавец")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("всемурчащее высочество петух")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("всемурчащее высочество петух")[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
